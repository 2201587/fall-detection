# %%
import numpy as np
from pathlib import Path
import json

# Define sequence segmentation method
def segment_sequence(sequence_length, keypoints):
    num_frames = len(keypoints)
    clips = []
    
    # Sliding window - only create complete clips
    for start_idx in range(0, num_frames - sequence_length + 1, sequence_length):
        end_idx = start_idx + sequence_length
        clip = keypoints[start_idx:end_idx]
        
        # Verify clip has correct length
        assert len(clip) == sequence_length, f"Clip has wrong length: {len(clip)}"
        
        clips.append(clip)
    
    return clips

# MAIN
input_dir = "data/extracted_keypoints"
output_dir = "data/segmented_clips"
input_path = Path(input_dir)
output_path = Path(output_dir)
output_path.mkdir(parents=True, exist_ok=True)
    
# Configuration
sequence_length = 60  # 60 frames = 2 seconds at 30fps

# Load metadata from extraction step
metadata_file = input_path / 'extraction_metadata.json'
if not metadata_file.exists():
    raise ValueError(f"Metadata file not found: {metadata_file}")

with open(metadata_file, 'r') as f:
    extraction_metadata = json.load(f)

print(f"Found {len(extraction_metadata)} keypoint sequences to segment\n")

all_clips_metadata = []
total_clips = 0
discarded_frames = 0
total_frames = 0

# Iterate through videos
for i, (video_name, info) in enumerate(extraction_metadata.items(), 1):
    print(f"[{i}/{len(extraction_metadata)}] {video_name}")
    
    # Load keypoints
    keypoints_file = info['keypoints_file']
    keypoints = np.load(keypoints_file)
    
    num_frames = len(keypoints)
    total_frames += num_frames
    
    # Segment into clips
    clips = segment_sequence(sequence_length, keypoints)
    
    # Calculate discarded frames
    frames_used = len(clips) * sequence_length
    frames_discarded = num_frames - frames_used
    discarded_frames += frames_discarded
    
    print(f"  {num_frames} frames → {len(clips)} clips "
          f"({frames_discarded} frames discarded)")
    
    # Save each clip
    for clip_idx, clip in enumerate(clips):
        # Create output filename
        clip_filename = output_path / f"{video_name}_clip{clip_idx:03d}.npy"
        
        # Create parent directories if needed
        clip_filename.parent.mkdir(parents=True, exist_ok=True)
        
        # Save clip
        np.save(clip_filename, clip)
        
        # Store metadata for this clip
        all_clips_metadata.append({
            'clip_file': str(clip_filename),
            'original_video': video_name,
            'original_video_category': info['category'],
            'clip_index': clip_idx,
            'num_clips_from_video': len(clips),
            'sequence_length': sequence_length,
            'start_frame': clip_idx * sequence_length,
            'end_frame': (clip_idx * sequence_length) + sequence_length,
            'clip_shape': list(clip.shape),
            'width': info['width'],
            'height': info['height'],
            'resolution': info['resolution']
        })
        
        total_clips += 1
    
    if i % 100 == 0:
        print(f"\n--- Progress: {i}/{len(extraction_metadata)} ---")
        print(f"    Clips created so far: {total_clips}\n")

# Save clips metadata
clips_metadata_file = output_path / 'clips_metadata.json'
with open(clips_metadata_file, 'w') as f:
    json.dump(all_clips_metadata, f, indent=2)

# Print summary
print("\n" + "=" * 70)
print("SEGMENTATION COMPLETE")
print("=" * 70)
print(f"Total videos processed: {len(extraction_metadata)}")
print(f"Total clips created: {total_clips}")
print(f"Average clips per video: {total_clips/len(extraction_metadata):.1f}")
print(f"\nFrame usage:")
print(f"  Total frames: {total_frames}")
print(f"  Frames in clips: {total_clips * sequence_length}")
print(f"  Frames discarded: {discarded_frames} ({discarded_frames/total_frames*100:.1f}%)")
print(f"\nMetadata saved to: {clips_metadata_file}")
print(f"Clips saved to: {output_path}")
# Out:
# Segmenter initialized:
#   Sequence length: 60 frames
#   Overlap: 0.0%
#   Step size: 60 frames
#
# Found 5672 keypoint sequences to segment
#
# [1/5672] no-fall/bed/nf_raw_b_2/B_N_46
#   96 frames → 1 clips (36 frames discarded)
# [2/5672] no-fall/bed/nf_raw_b_2/B_N_76_resized
#   90 frames → 1 clips (30 frames discarded)
# [3/5672] no-fall/bed/nf_raw_b_2/B_N_67_resized
#   120 frames → 2 clips (0 frames discarded)
# [4/5672] no-fall/bed/nf_raw_b_2/B_N_99
#   150 frames → 2 clips (30 frames discarded)
# [5/5672] no-fall/bed/nf_raw_b_2/B_N_62_resized
#   48 frames → 0 clips (48 frames discarded)
# [6/5672] no-fall/bed/nf_raw_b_2/B_N_54_resized
#   24 frames → 0 clips (24 frames discarded)
# [7/5672] no-fall/bed/nf_raw_b_2/B_N_17
#   90 frames → 1 clips (30 frames discarded)
# [8/5672] no-fall/bed/nf_raw_b_2/B_N_01
#   90 frames → 1 clips (30 frames discarded)
# [9/5672] no-fall/bed/nf_raw_b_2/B_N_63_resized
#   48 frames → 0 clips (48 frames discarded)
# [10/5672] no-fall/bed/nf_raw_b_2/B_N_11
#   90 frames → 1 clips (30 frames discarded)
# [11/5672] no-fall/bed/nf_raw_b_2/B_N_78_resized
#   60 frames → 1 clips (0 frames discarded)
# [12/5672] no-fall/bed/nf_raw_b_2/B_N_80_resized
#   119 frames → 1 clips (59 frames discarded)
# [13/5672] no-fall/bed/nf_raw_b_2/B_N_104
#   120 frames → 2 clips (0 frames discarded)
# [14/5672] no-fall/bed/nf_raw_b_2/B_N_64_resized
#   48 frames → 0 clips (48 frames discarded)
# [15/5672] no-fall/bed/nf_raw_b_2/B_N_74_resized
#   90 frames → 1 clips (30 frames discarded)
# [16/5672] no-fall/bed/nf_raw_b_2/B_N_68_resized
#   90 frames → 1 clips (30 frames discarded)
# [17/5672] no-fall/bed/nf_raw_b_2/B_N_93
#   240 frames → 4 clips (0 frames discarded)
# [18/5672] no-fall/bed/nf_raw_b_2/B_N_107_resized
#   90 frames → 1 clips (30 frames discarded)
# [19/5672] no-fall/bed/nf_raw_b_2/B_N_73_resized
#   90 frames → 1 clips (30 frames discarded)
# [20/5672] no-fall/bed/nf_raw_b_2/B_N_53_resized
#   24 frames → 0 clips (24 frames discarded)
# [21/5672] no-fall/bed/nf_raw_b_2/B_N_60
#   60 frames → 1 clips (0 frames discarded)
# [22/5672] no-fall/bed/nf_raw_b_2/B_N_07
#   90 frames → 1 clips (30 frames discarded)
# [23/5672] no-fall/bed/nf_raw_b_2/B_N_15
#   90 frames → 1 clips (30 frames discarded)
# [24/5672] no-fall/bed/nf_raw_b_2/B_N_96
#   180 frames → 3 clips (0 frames discarded)
# [25/5672] no-fall/bed/nf_raw_b_2/B_N_75_resized
#   150 frames → 2 clips (30 frames discarded)
# [26/5672] no-fall/bed/nf_raw_b_2/B_N_16
#   90 frames → 1 clips (30 frames discarded)
# [27/5672] no-fall/bed/nf_raw_b_2/B_N_13
#   90 frames → 1 clips (30 frames discarded)
# [28/5672] no-fall/bed/nf_raw_b_2/B_N_114
#   120 frames → 2 clips (0 frames discarded)
# [29/5672] no-fall/bed/nf_raw_b_2/B_N_70_resized
#   150 frames → 2 clips (30 frames discarded)
# [30/5672] no-fall/bed/nf_raw_b_2/B_N_12
#   90 frames → 1 clips (30 frames discarded)
# [31/5672] no-fall/bed/nf_raw_b_2/B_N_06
#   90 frames → 1 clips (30 frames discarded)
# [32/5672] no-fall/bed/nf_raw_b_2/B_N_100
#   150 frames → 2 clips (30 frames discarded)
# [33/5672] no-fall/bed/nf_raw_b_2/B_N_109_resized
#   90 frames → 1 clips (30 frames discarded)
# [34/5672] no-fall/bed/nf_raw_b_2/B_N_77_resized
#   90 frames → 1 clips (30 frames discarded)
# [35/5672] no-fall/bed/nf_raw_b_2/B_N_52_resized
#   24 frames → 0 clips (24 frames discarded)
# [36/5672] no-fall/bed/nf_raw_b_2/B_N_87_resized
#   120 frames → 2 clips (0 frames discarded)
# [37/5672] no-fall/bed/nf_raw_b_2/B_N_88_resized
#   120 frames → 2 clips (0 frames discarded)
# [38/5672] no-fall/bed/nf_raw_b_2/B_N_101
#   150 frames → 2 clips (30 frames discarded)
# [39/5672] no-fall/bed/nf_raw_b_2/B_N_19
#   90 frames → 1 clips (30 frames discarded)
# [40/5672] no-fall/bed/nf_raw_b_2/B_N_03
#   90 frames → 1 clips (30 frames discarded)
# [41/5672] no-fall/bed/nf_raw_b_2/B_N_41
#   96 frames → 1 clips (36 frames discarded)
# [42/5672] no-fall/bed/nf_raw_b_2/B_N_50_resized
#   24 frames → 0 clips (24 frames discarded)
# [43/5672] no-fall/bed/nf_raw_b_2/B_N_66_resized
#   48 frames → 0 clips (48 frames discarded)
# [44/5672] no-fall/bed/nf_raw_b_2/B_N_105
#   120 frames → 2 clips (0 frames discarded)
# [45/5672] no-fall/bed/nf_raw_b_2/B_N_09
#   120 frames → 2 clips (0 frames discarded)
# [46/5672] no-fall/bed/nf_raw_b_2/B_N_79_resized
#   60 frames → 1 clips (0 frames discarded)
# [47/5672] no-fall/bed/nf_raw_b_2/B_N_43
#   96 frames → 1 clips (36 frames discarded)
# [48/5672] no-fall/bed/nf_raw_b_2/B_N_92
#   150 frames → 2 clips (30 frames discarded)
# [49/5672] no-fall/bed/nf_raw_b_2/B_N_58
#   60 frames → 1 clips (0 frames discarded)
# [50/5672] no-fall/bed/nf_raw_b_2/B_N_04
#   90 frames → 1 clips (30 frames discarded)
# [51/5672] no-fall/bed/nf_raw_b_2/B_N_48_resized
#   24 frames → 0 clips (24 frames discarded)
# [52/5672] no-fall/bed/nf_raw_b_2/B_N_45
#   96 frames → 1 clips (36 frames discarded)
# [53/5672] no-fall/bed/nf_raw_b_2/B_N_102
#   120 frames → 2 clips (0 frames discarded)
# [54/5672] no-fall/bed/nf_raw_b_2/B_N_08
#   120 frames → 2 clips (0 frames discarded)
# [55/5672] no-fall/bed/nf_raw_b_2/B_N_111_resized
#   90 frames → 1 clips (30 frames discarded)
# [56/5672] no-fall/bed/nf_raw_b_2/B_N_18
#   60 frames → 1 clips (0 frames discarded)
# [57/5672] no-fall/bed/nf_raw_b_2/B_N_97
#   120 frames → 2 clips (0 frames discarded)
# [58/5672] no-fall/bed/nf_raw_b_2/B_N_61
#   60 frames → 1 clips (0 frames discarded)
# [59/5672] no-fall/bed/nf_raw_b_2/B_N_91_resized
#   144 frames → 2 clips (24 frames discarded)
# [60/5672] no-fall/bed/nf_raw_b_2/B_N_55_resized
#   24 frames → 0 clips (24 frames discarded)
# [61/5672] no-fall/bed/nf_raw_b_2/B_N_42
#   96 frames → 1 clips (36 frames discarded)
# [62/5672] no-fall/bed/nf_raw_b_2/B_N_20
#   90 frames → 1 clips (30 frames discarded)
# [63/5672] no-fall/bed/nf_raw_b_2/B_N_95
#   150 frames → 2 clips (30 frames discarded)
# [64/5672] no-fall/bed/nf_raw_b_2/B_N_49_resized
#   24 frames → 0 clips (24 frames discarded)
# [65/5672] no-fall/bed/nf_raw_b_2/B_N_69_resized
#   90 frames → 1 clips (30 frames discarded)
# [66/5672] no-fall/bed/nf_raw_b_2/B_N_47_resized
#   24 frames → 0 clips (24 frames discarded)
# [67/5672] no-fall/bed/nf_raw_b_2/B_N_90_resized
#   120 frames → 2 clips (0 frames discarded)
# [68/5672] no-fall/bed/nf_raw_b_2/B_N_98
#   150 frames → 2 clips (30 frames discarded)
# [69/5672] no-fall/bed/nf_raw_b_2/B_N_112
#   96 frames → 1 clips (36 frames discarded)
# [70/5672] no-fall/bed/nf_raw_b_2/B_N_71_resized
#   60 frames → 1 clips (0 frames discarded)
# [71/5672] no-fall/bed/nf_raw_b_2/B_N_89_resized
#   120 frames → 2 clips (0 frames discarded)
# [72/5672] no-fall/bed/nf_raw_b_2/B_N_51_resized
#   24 frames → 0 clips (24 frames discarded)
# [73/5672] no-fall/bed/nf_raw_b_2/B_N_65_resized
#   48 frames → 0 clips (48 frames discarded)
# [74/5672] no-fall/bed/nf_raw_b_2/B_N_81_resized
#   60 frames → 1 clips (0 frames discarded)
# [75/5672] no-fall/bed/nf_raw_b_2/B_N_106
#   120 frames → 2 clips (0 frames discarded)
# [76/5672] no-fall/bed/nf_raw_b_2/B_N_113
#   72 frames → 1 clips (12 frames discarded)
# [77/5672] no-fall/bed/nf_raw_b_2/B_N_103
#   150 frames → 2 clips (30 frames discarded)
# [78/5672] no-fall/bed/nf_raw_b_2/B_N_10
#   90 frames → 1 clips (30 frames discarded)
# [79/5672] no-fall/bed/nf_raw_b_2/B_N_110_resized
#   90 frames → 1 clips (30 frames discarded)
# [80/5672] no-fall/bed/nf_raw_b_2/B_N_02
#   90 frames → 1 clips (30 frames discarded)
# [81/5672] no-fall/bed/nf_raw_b_2/B_N_14
#   90 frames → 1 clips (30 frames discarded)
# [82/5672] no-fall/bed/nf_raw_b_2/B_N_44
#   96 frames → 1 clips (36 frames discarded)
# [83/5672] no-fall/bed/nf_raw_b_2/B_N_108_resized
#   60 frames → 1 clips (0 frames discarded)
# [84/5672] no-fall/bed/nf_raw_b_2/B_N_59
#   60 frames → 1 clips (0 frames discarded)
# [85/5672] no-fall/bed/nf_raw_b_2/B_N_94
#   210 frames → 3 clips (30 frames discarded)
# [86/5672] no-fall/bed/nf_raw_b_2/B_N_56_resized
#   24 frames → 0 clips (24 frames discarded)
# [87/5672] no-fall/bed/nf_raw_b_2/B_N_72_resized
#   120 frames → 2 clips (0 frames discarded)
# [88/5672] no-fall/bed/nf_raw_b_2/B_N_57
#   60 frames → 1 clips (0 frames discarded)
# [89/5672] no-fall/bed/nf_raw_b_4/B_D_0154
#   30 frames → 0 clips (30 frames discarded)
# [90/5672] no-fall/bed/nf_raw_b_4/B_D_0018
#   90 frames → 1 clips (30 frames discarded)
# [91/5672] no-fall/bed/nf_raw_b_4/B_D_0229
#   120 frames → 2 clips (0 frames discarded)
# [92/5672] no-fall/bed/nf_raw_b_4/B_D_0117
#   90 frames → 1 clips (30 frames discarded)
# [93/5672] no-fall/bed/nf_raw_b_4/B_D_0026
#   120 frames → 2 clips (0 frames discarded)
# [94/5672] no-fall/bed/nf_raw_b_4/B_D_0252
#   150 frames → 2 clips (30 frames discarded)
# [95/5672] no-fall/bed/nf_raw_b_4/B_D_0163
#   90 frames → 1 clips (30 frames discarded)
# [96/5672] no-fall/bed/nf_raw_b_4/B_D_0237
#   60 frames → 1 clips (0 frames discarded)
# [97/5672] no-fall/bed/nf_raw_b_4/B_D_0011
#   120 frames → 2 clips (0 frames discarded)
# [98/5672] no-fall/bed/nf_raw_b_4/B_D_0256
#   150 frames → 2 clips (30 frames discarded)
# [99/5672] no-fall/bed/nf_raw_b_4/B_D_0096
#   48 frames → 0 clips (48 frames discarded)
# [100/5672] no-fall/bed/nf_raw_b_4/B_D_0114
#   90 frames → 1 clips (30 frames discarded)
#
# --- Progress: 100/5672 ---
#     Clips created so far: 119
#
# [101/5672] no-fall/bed/nf_raw_b_4/B_D_0176
#   120 frames → 2 clips (0 frames discarded)
# [102/5672] no-fall/bed/nf_raw_b_4/B_D_0020
#   120 frames → 2 clips (0 frames discarded)
# [103/5672] no-fall/bed/nf_raw_b_4/B_D_0115
#   90 frames → 1 clips (30 frames discarded)
# [104/5672] no-fall/bed/nf_raw_b_4/B_D_0105
#   120 frames → 2 clips (0 frames discarded)
# [105/5672] no-fall/bed/nf_raw_b_4/B_D_0255
#   120 frames → 2 clips (0 frames discarded)
# [106/5672] no-fall/bed/nf_raw_b_4/B_D_0097
#   72 frames → 1 clips (12 frames discarded)
# [107/5672] no-fall/bed/nf_raw_b_4/B_D_0156
#   120 frames → 2 clips (0 frames discarded)
# [108/5672] no-fall/bed/nf_raw_b_4/B_D_0152
#   60 frames → 1 clips (0 frames discarded)
# [109/5672] no-fall/bed/nf_raw_b_4/B_D_0102
#   90 frames → 1 clips (30 frames discarded)
# [110/5672] no-fall/bed/nf_raw_b_4/B_D_0031
#   120 frames → 2 clips (0 frames discarded)
# [111/5672] no-fall/bed/nf_raw_b_4/B_D_0112
#   90 frames → 1 clips (30 frames discarded)
# [112/5672] no-fall/bed/nf_raw_b_4/B_D_0089_resized
#   72 frames → 1 clips (12 frames discarded)
# [113/5672] no-fall/bed/nf_raw_b_4/B_D_0058
#   90 frames → 1 clips (30 frames discarded)
# [114/5672] no-fall/bed/nf_raw_b_4/B_D_0194
#   90 frames → 1 clips (30 frames discarded)
# [115/5672] no-fall/bed/nf_raw_b_4/B_D_0160
#   90 frames → 1 clips (30 frames discarded)
# [116/5672] no-fall/bed/nf_raw_b_4/B_D_0023
#   120 frames → 2 clips (0 frames discarded)
# [117/5672] no-fall/bed/nf_raw_b_4/B_D_0170
#   150 frames → 2 clips (30 frames discarded)
# [118/5672] no-fall/bed/nf_raw_b_4/B_D_0249
#   150 frames → 2 clips (30 frames discarded)
# [119/5672] no-fall/bed/nf_raw_b_4/B_D_0157
#   90 frames → 1 clips (30 frames discarded)
# [120/5672] no-fall/bed/nf_raw_b_4/B_D_0010_resized
#   120 frames → 2 clips (0 frames discarded)
# [121/5672] no-fall/bed/nf_raw_b_4/B_D_0019
#   120 frames → 2 clips (0 frames discarded)
# [122/5672] no-fall/bed/nf_raw_b_4/B_D_0148
#   60 frames → 1 clips (0 frames discarded)
# [123/5672] no-fall/bed/nf_raw_b_4/B_D_0158
#   90 frames → 1 clips (30 frames discarded)
# [124/5672] no-fall/bed/nf_raw_b_4/B_D_0254
#   120 frames → 2 clips (0 frames discarded)
# [125/5672] no-fall/bed/nf_raw_b_4/B_D_0101
#   90 frames → 1 clips (30 frames discarded)
# [126/5672] no-fall/bed/nf_raw_b_4/B_D_0057
#   90 frames → 1 clips (30 frames discarded)
# [127/5672] no-fall/bed/nf_raw_b_4/B_D_0032
#   120 frames → 2 clips (0 frames discarded)
# [128/5672] no-fall/bed/nf_raw_b_4/B_D_0055
#   90 frames → 1 clips (30 frames discarded)
# [129/5672] no-fall/bed/nf_raw_b_4/B_D_0221
#   120 frames → 2 clips (0 frames discarded)
# [130/5672] no-fall/bed/nf_raw_b_4/B_D_0104
#   120 frames → 2 clips (0 frames discarded)
# [131/5672] no-fall/bed/nf_raw_b_4/B_D_0149
#   60 frames → 1 clips (0 frames discarded)
# [132/5672] no-fall/bed/nf_raw_b_4/B_D_0211
#   120 frames → 2 clips (0 frames discarded)
# [133/5672] no-fall/bed/nf_raw_b_4/B_D_0201
#   90 frames → 1 clips (30 frames discarded)
# [134/5672] no-fall/bed/nf_raw_b_4/B_D_0216
#   120 frames → 2 clips (0 frames discarded)
# [135/5672] no-fall/bed/nf_raw_b_4/B_D_0166
#   90 frames → 1 clips (30 frames discarded)
# [136/5672] no-fall/bed/nf_raw_b_4/B_D_0064
#   90 frames → 1 clips (30 frames discarded)
# [137/5672] no-fall/bed/nf_raw_b_4/B_D_0144
#   60 frames → 1 clips (0 frames discarded)
# [138/5672] no-fall/bed/nf_raw_b_4/B_D_0049
#   120 frames → 2 clips (0 frames discarded)
# [139/5672] no-fall/bed/nf_raw_b_4/B_D_0251
#   150 frames → 2 clips (30 frames discarded)
# [140/5672] no-fall/bed/nf_raw_b_4/B_D_0052
#   120 frames → 2 clips (0 frames discarded)
# [141/5672] no-fall/bed/nf_raw_b_4/B_D_0110
#   90 frames → 1 clips (30 frames discarded)
# [142/5672] no-fall/bed/nf_raw_b_4/B_D_0113
#   90 frames → 1 clips (30 frames discarded)
# [143/5672] no-fall/bed/nf_raw_b_4/B_D_0153
#   90 frames → 1 clips (30 frames discarded)
# [144/5672] no-fall/bed/nf_raw_b_4/B_D_0231
#   90 frames → 1 clips (30 frames discarded)
# [145/5672] no-fall/bed/nf_raw_b_4/B_D_0150
#   60 frames → 1 clips (0 frames discarded)
# [146/5672] no-fall/bed/nf_raw_b_4/B_D_0073
#   90 frames → 1 clips (30 frames discarded)
# [147/5672] no-fall/bed/nf_raw_b_4/B_D_0107
#   120 frames → 2 clips (0 frames discarded)
# [148/5672] no-fall/bed/nf_raw_b_4/B_D_0022
#   90 frames → 1 clips (30 frames discarded)
# [149/5672] no-fall/bed/nf_raw_b_4/B_D_0164
#   90 frames → 1 clips (30 frames discarded)
# [150/5672] no-fall/bed/nf_raw_b_4/B_D_0172
#   180 frames → 3 clips (0 frames discarded)
# [151/5672] no-fall/bed/nf_raw_b_4/B_D_0060
#   90 frames → 1 clips (30 frames discarded)
# [152/5672] no-fall/bed/nf_raw_b_4/B_D_0108
#   90 frames → 1 clips (30 frames discarded)
# [153/5672] no-fall/bed/nf_raw_b_4/B_D_0219
#   120 frames → 2 clips (0 frames discarded)
# [154/5672] no-fall/bed/nf_raw_b_4/B_D_0041
#   120 frames → 2 clips (0 frames discarded)
# [155/5672] no-fall/bed/nf_raw_b_4/B_D_0146
#   60 frames → 1 clips (0 frames discarded)
# [156/5672] no-fall/bed/nf_raw_b_4/B_D_0234
#   90 frames → 1 clips (30 frames discarded)
# [157/5672] no-fall/bed/nf_raw_b_4/B_D_0088_resized
#   72 frames → 1 clips (12 frames discarded)
# [158/5672] no-fall/bed/nf_raw_b_4/B_D_0013
#   90 frames → 1 clips (30 frames discarded)
# [159/5672] no-fall/bed/nf_raw_b_4/B_D_0209
#   120 frames → 2 clips (0 frames discarded)
# [160/5672] no-fall/bed/nf_raw_b_4/B_D_0016
#   60 frames → 1 clips (0 frames discarded)
# [161/5672] no-fall/bed/nf_raw_b_4/B_D_0065
#   90 frames → 1 clips (30 frames discarded)
# [162/5672] no-fall/bed/nf_raw_b_4/B_D_0094_resized
#   48 frames → 0 clips (48 frames discarded)
# [163/5672] no-fall/bed/nf_raw_b_4/B_D_0051
#   90 frames → 1 clips (30 frames discarded)
# [164/5672] no-fall/bed/nf_raw_b_4/B_D_0090_resized
#   48 frames → 0 clips (48 frames discarded)
# [165/5672] no-fall/bed/nf_raw_b_4/B_D_0258
#   180 frames → 3 clips (0 frames discarded)
# [166/5672] no-fall/bed/nf_raw_b_4/B_D_0009_resized
#   120 frames → 2 clips (0 frames discarded)
# [167/5672] no-fall/bed/nf_raw_b_4/B_D_0070
#   90 frames → 1 clips (30 frames discarded)
# [168/5672] no-fall/bed/nf_raw_b_4/B_D_0143
#   60 frames → 1 clips (0 frames discarded)
# [169/5672] no-fall/bed/nf_raw_b_4/B_D_0199
#   90 frames → 1 clips (30 frames discarded)
# [170/5672] no-fall/bed/nf_raw_b_4/B_D_0165
#   150 frames → 2 clips (30 frames discarded)
# [171/5672] no-fall/bed/nf_raw_b_4/B_D_0204
#   120 frames → 2 clips (0 frames discarded)
# [172/5672] no-fall/bed/nf_raw_b_4/B_D_0243
#   150 frames → 2 clips (30 frames discarded)
# [173/5672] no-fall/bed/nf_raw_b_4/B_D_0005
#   90 frames → 1 clips (30 frames discarded)
# [174/5672] no-fall/bed/nf_raw_b_4/B_D_0003
#   120 frames → 2 clips (0 frames discarded)
# [175/5672] no-fall/bed/nf_raw_b_4/B_D_0111
#   90 frames → 1 clips (30 frames discarded)
# [176/5672] no-fall/bed/nf_raw_b_4/B_D_0147
#   60 frames → 1 clips (0 frames discarded)
# [177/5672] no-fall/bed/nf_raw_b_4/B_D_0076
#   90 frames → 1 clips (30 frames discarded)
# [178/5672] no-fall/bed/nf_raw_b_4/B_D_0169_resized
#   30 frames → 0 clips (30 frames discarded)
# [179/5672] no-fall/bed/nf_raw_b_4/B_D_0040
#   60 frames → 1 clips (0 frames discarded)
# [180/5672] no-fall/bed/nf_raw_b_4/B_D_0021
#   90 frames → 1 clips (30 frames discarded)
# [181/5672] no-fall/bed/nf_raw_b_4/B_D_0239
#   90 frames → 1 clips (30 frames discarded)
# [182/5672] no-fall/bed/nf_raw_b_4/B_D_0195
#   90 frames → 1 clips (30 frames discarded)
# [183/5672] no-fall/bed/nf_raw_b_4/B_D_0207
#   120 frames → 2 clips (0 frames discarded)
# [184/5672] no-fall/bed/nf_raw_b_4/B_D_0159
#   90 frames → 1 clips (30 frames discarded)
# [185/5672] no-fall/bed/nf_raw_b_4/B_D_0230
#   120 frames → 2 clips (0 frames discarded)
# [186/5672] no-fall/bed/nf_raw_b_4/B_D_0116
#   90 frames → 1 clips (30 frames discarded)
# [187/5672] no-fall/bed/nf_raw_b_4/B_D_0001
#   150 frames → 2 clips (30 frames discarded)
# [188/5672] no-fall/bed/nf_raw_b_4/B_D_0227_resized
#   90 frames → 1 clips (30 frames discarded)
# [189/5672] no-fall/bed/nf_raw_b_4/B_D_0027
#   60 frames → 1 clips (0 frames discarded)
# [190/5672] no-fall/bed/nf_raw_b_4/B_D_0029
#   120 frames → 2 clips (0 frames discarded)
# [191/5672] no-fall/bed/nf_raw_b_4/B_D_0224_resized
#   30 frames → 0 clips (30 frames discarded)
# [192/5672] no-fall/bed/nf_raw_b_4/B_D_0203
#   120 frames → 2 clips (0 frames discarded)
# [193/5672] no-fall/bed/nf_raw_b_4/B_D_0050
#   90 frames → 1 clips (30 frames discarded)
# [194/5672] no-fall/bed/nf_raw_b_4/B_D_0253
#   120 frames → 2 clips (0 frames discarded)
# [195/5672] no-fall/bed/nf_raw_b_4/B_D_0093_resized
#   48 frames → 0 clips (48 frames discarded)
# [196/5672] no-fall/bed/nf_raw_b_4/B_D_0215
#   120 frames → 2 clips (0 frames discarded)
# [197/5672] no-fall/bed/nf_raw_b_4/B_D_0068
#   90 frames → 1 clips (30 frames discarded)
# [198/5672] no-fall/bed/nf_raw_b_4/B_D_0059
#   90 frames → 1 clips (30 frames discarded)
# [199/5672] no-fall/bed/nf_raw_b_4/B_D_0155
#   90 frames → 1 clips (30 frames discarded)
# [200/5672] no-fall/bed/nf_raw_b_4/B_D_0054
#   60 frames → 1 clips (0 frames discarded)
#
# --- Progress: 200/5672 ---
#     Clips created so far: 254
#
# [201/5672] no-fall/bed/nf_raw_b_4/B_D_0004
#   60 frames → 1 clips (0 frames discarded)
# [202/5672] no-fall/bed/nf_raw_b_4/B_D_0006_resized
#   90 frames → 1 clips (30 frames discarded)
# [203/5672] no-fall/bed/nf_raw_b_4/B_D_0257
#   150 frames → 2 clips (30 frames discarded)
# [204/5672] no-fall/bed/nf_raw_b_4/B_D_0071
#   90 frames → 1 clips (30 frames discarded)
# [205/5672] no-fall/bed/nf_raw_b_4/B_D_0038
#   120 frames → 2 clips (0 frames discarded)
# [206/5672] no-fall/bed/nf_raw_b_4/B_D_0039
#   90 frames → 1 clips (30 frames discarded)
# [207/5672] no-fall/bed/nf_raw_b_4/B_D_0233
#   120 frames → 2 clips (0 frames discarded)
# [208/5672] no-fall/bed/nf_raw_b_4/B_D_0008_resized
#   90 frames → 1 clips (30 frames discarded)
# [209/5672] no-fall/bed/nf_raw_b_4/B_D_0235
#   30 frames → 0 clips (30 frames discarded)
# [210/5672] no-fall/bed/nf_raw_b_4/B_D_0037
#   150 frames → 2 clips (30 frames discarded)
# [211/5672] no-fall/bed/nf_raw_b_4/B_D_0247
#   90 frames → 1 clips (30 frames discarded)
# [212/5672] no-fall/bed/nf_raw_b_4/B_D_0066
#   90 frames → 1 clips (30 frames discarded)
# [213/5672] no-fall/bed/nf_raw_b_4/B_D_0175
#   120 frames → 2 clips (0 frames discarded)
# [214/5672] no-fall/bed/nf_raw_b_4/B_D_0242
#   150 frames → 2 clips (30 frames discarded)
# [215/5672] no-fall/bed/nf_raw_b_4/B_D_0208
#   120 frames → 2 clips (0 frames discarded)
# [216/5672] no-fall/bed/nf_raw_b_4/B_D_0048
#   120 frames → 2 clips (0 frames discarded)
# [217/5672] no-fall/bed/nf_raw_b_4/B_D_0042
#   60 frames → 1 clips (0 frames discarded)
# [218/5672] no-fall/bed/nf_raw_b_4/B_D_0033
#   120 frames → 2 clips (0 frames discarded)
# [219/5672] no-fall/bed/nf_raw_b_4/B_D_0223_resized
#   90 frames → 1 clips (30 frames discarded)
# [220/5672] no-fall/bed/nf_raw_b_4/B_D_0086_resized
#   72 frames → 1 clips (12 frames discarded)
# [221/5672] no-fall/bed/nf_raw_b_4/B_D_0244
#   90 frames → 1 clips (30 frames discarded)
# [222/5672] no-fall/bed/nf_raw_b_4/B_D_0091_resized
#   72 frames → 1 clips (12 frames discarded)
# [223/5672] no-fall/bed/nf_raw_b_4/B_D_0098
#   48 frames → 0 clips (48 frames discarded)
# [224/5672] no-fall/bed/nf_raw_b_4/B_D_0095_resized
#   48 frames → 0 clips (48 frames discarded)
# [225/5672] no-fall/bed/nf_raw_b_4/B_D_0017
#   90 frames → 1 clips (30 frames discarded)
# [226/5672] no-fall/bed/nf_raw_b_4/B_D_0241
#   120 frames → 2 clips (0 frames discarded)
# [227/5672] no-fall/bed/nf_raw_b_4/B_D_0012
#   120 frames → 2 clips (0 frames discarded)
# [228/5672] no-fall/bed/nf_raw_b_4/B_D_0173
#   150 frames → 2 clips (30 frames discarded)
# [229/5672] no-fall/bed/nf_raw_b_4/B_D_0217
#   120 frames → 2 clips (0 frames discarded)
# [230/5672] no-fall/bed/nf_raw_b_4/B_D_0193
#   90 frames → 1 clips (30 frames discarded)
# [231/5672] no-fall/bed/nf_raw_b_4/B_D_0248
#   120 frames → 2 clips (0 frames discarded)
# [232/5672] no-fall/bed/nf_raw_b_4/B_D_0206
#   120 frames → 2 clips (0 frames discarded)
# [233/5672] no-fall/bed/nf_raw_b_4/B_D_0218
#   120 frames → 2 clips (0 frames discarded)
# [234/5672] no-fall/bed/nf_raw_b_4/B_D_0014
#   90 frames → 1 clips (30 frames discarded)
# [235/5672] no-fall/bed/nf_raw_b_4/B_D_0240
#   120 frames → 2 clips (0 frames discarded)
# [236/5672] no-fall/bed/nf_raw_b_4/B_D_0061
#   60 frames → 1 clips (0 frames discarded)
# [237/5672] no-fall/bed/nf_raw_b_4/B_D_0197
#   90 frames → 1 clips (30 frames discarded)
# [238/5672] no-fall/bed/nf_raw_b_4/B_D_0177
#   120 frames → 2 clips (0 frames discarded)
# [239/5672] no-fall/bed/nf_raw_b_4/B_D_0063
#   90 frames → 1 clips (30 frames discarded)
# [240/5672] no-fall/bed/nf_raw_b_4/B_D_0250
#   120 frames → 2 clips (0 frames discarded)
# [241/5672] no-fall/bed/nf_raw_b_4/B_D_0035
#   120 frames → 2 clips (0 frames discarded)
# [242/5672] no-fall/bed/nf_raw_b_4/B_D_0053
#   90 frames → 1 clips (30 frames discarded)
# [243/5672] no-fall/bed/nf_raw_b_4/B_D_0226_resized
#   120 frames → 2 clips (0 frames discarded)
# [244/5672] no-fall/bed/nf_raw_b_4/B_D_0210
#   180 frames → 3 clips (0 frames discarded)
# [245/5672] no-fall/bed/nf_raw_b_4/B_D_0171
#   150 frames → 2 clips (30 frames discarded)
# [246/5672] no-fall/bed/nf_raw_b_4/B_D_0030
#   150 frames → 2 clips (30 frames discarded)
# [247/5672] no-fall/bed/nf_raw_b_4/B_D_0100
#   72 frames → 1 clips (12 frames discarded)
# [248/5672] no-fall/bed/nf_raw_b_4/B_D_0196
#   90 frames → 1 clips (30 frames discarded)
# [249/5672] no-fall/bed/nf_raw_b_4/B_D_0044
#   90 frames → 1 clips (30 frames discarded)
# [250/5672] no-fall/bed/nf_raw_b_4/B_D_0074
#   90 frames → 1 clips (30 frames discarded)
# [251/5672] no-fall/bed/nf_raw_b_4/B_D_0220
#   120 frames → 2 clips (0 frames discarded)
# [252/5672] no-fall/bed/nf_raw_b_4/B_D_0174_resized
#   120 frames → 2 clips (0 frames discarded)
# [253/5672] no-fall/bed/nf_raw_b_4/B_D_0238
#   120 frames → 2 clips (0 frames discarded)
# [254/5672] no-fall/bed/nf_raw_b_4/B_D_0062
#   90 frames → 1 clips (30 frames discarded)
# [255/5672] no-fall/bed/nf_raw_b_4/B_D_0002
#   60 frames → 1 clips (0 frames discarded)
# [256/5672] no-fall/bed/nf_raw_b_4/B_D_0015
#   90 frames → 1 clips (30 frames discarded)
# [257/5672] no-fall/bed/nf_raw_b_4/B_D_0214
#   120 frames → 2 clips (0 frames discarded)
# [258/5672] no-fall/bed/nf_raw_b_4/B_D_0036
#   120 frames → 2 clips (0 frames discarded)
# [259/5672] no-fall/bed/nf_raw_b_4/B_D_0213
#   120 frames → 2 clips (0 frames discarded)
# [260/5672] no-fall/bed/nf_raw_b_4/B_D_0067
#   90 frames → 1 clips (30 frames discarded)
# [261/5672] no-fall/bed/nf_raw_b_4/B_D_0212
#   120 frames → 2 clips (0 frames discarded)
# [262/5672] no-fall/bed/nf_raw_b_4/B_D_0205
#   120 frames → 2 clips (0 frames discarded)
# [263/5672] no-fall/bed/nf_raw_b_4/B_D_0024
#   120 frames → 2 clips (0 frames discarded)
# [264/5672] no-fall/bed/nf_raw_b_4/B_D_0046
#   60 frames → 1 clips (0 frames discarded)
# [265/5672] no-fall/bed/nf_raw_b_4/B_D_0072
#   90 frames → 1 clips (30 frames discarded)
# [266/5672] no-fall/bed/nf_raw_b_4/B_D_0109
#   90 frames → 1 clips (30 frames discarded)
# [267/5672] no-fall/bed/nf_raw_b_4/B_D_0198
#   90 frames → 1 clips (30 frames discarded)
# [268/5672] no-fall/bed/nf_raw_b_4/B_D_0045
#   90 frames → 1 clips (30 frames discarded)
# [269/5672] no-fall/bed/nf_raw_b_4/B_D_0245
#   180 frames → 3 clips (0 frames discarded)
# [270/5672] no-fall/bed/nf_raw_b_4/B_D_0200
#   90 frames → 1 clips (30 frames discarded)
# [271/5672] no-fall/bed/nf_raw_b_4/B_D_0025
#   120 frames → 2 clips (0 frames discarded)
# [272/5672] no-fall/bed/nf_raw_b_4/B_D_0246
#   120 frames → 2 clips (0 frames discarded)
# [273/5672] no-fall/bed/nf_raw_b_4/B_D_0151
#   60 frames → 1 clips (0 frames discarded)
# [274/5672] no-fall/bed/nf_raw_b_4/B_D_0087_resized
#   48 frames → 0 clips (48 frames discarded)
# [275/5672] no-fall/bed/nf_raw_b_4/B_D_0225_resized
#   120 frames → 2 clips (0 frames discarded)
# [276/5672] no-fall/bed/nf_raw_b_4/B_D_0043
#   90 frames → 1 clips (30 frames discarded)
# [277/5672] no-fall/bed/nf_raw_b_4/B_D_0202
#   90 frames → 1 clips (30 frames discarded)
# [278/5672] no-fall/bed/nf_raw_b_4/B_D_0103
#   90 frames → 1 clips (30 frames discarded)
# [279/5672] no-fall/bed/nf_raw_b_4/B_D_0236
#   120 frames → 2 clips (0 frames discarded)
# [280/5672] no-fall/bed/nf_raw_b_4/B_D_0092_resized
#   48 frames → 0 clips (48 frames discarded)
# [281/5672] no-fall/bed/nf_raw_b_4/B_D_0034
#   90 frames → 1 clips (30 frames discarded)
# [282/5672] no-fall/bed/nf_raw_b_4/B_D_0028
#   120 frames → 2 clips (0 frames discarded)
# [283/5672] no-fall/bed/nf_raw_b_4/B_D_0007_resized
#   60 frames → 1 clips (0 frames discarded)
# [284/5672] no-fall/bed/nf_raw_b_4/B_D_0145
#   60 frames → 1 clips (0 frames discarded)
# [285/5672] no-fall/bed/nf_raw_b_4/B_D_0056
#   90 frames → 1 clips (30 frames discarded)
# [286/5672] no-fall/bed/nf_raw_b_4/B_D_0106
#   120 frames → 2 clips (0 frames discarded)
# [287/5672] no-fall/bed/nf_raw_b_4/B_D_0099
#   72 frames → 1 clips (12 frames discarded)
# [288/5672] no-fall/bed/nf_raw_b_4/B_D_0075
#   90 frames → 1 clips (30 frames discarded)
# [289/5672] no-fall/bed/nf_raw_b_4/B_D_0167
#   150 frames → 2 clips (30 frames discarded)
# [290/5672] no-fall/bed/nf_raw_b_3/B_M_98
#   180 frames → 3 clips (0 frames discarded)
# [291/5672] no-fall/bed/nf_raw_b_3/B_M_134_resized
#   120 frames → 2 clips (0 frames discarded)
# [292/5672] no-fall/bed/nf_raw_b_3/B_M_165
#   120 frames → 2 clips (0 frames discarded)
# [293/5672] no-fall/bed/nf_raw_b_3/B_M_175
#   90 frames → 1 clips (30 frames discarded)
# [294/5672] no-fall/bed/nf_raw_b_3/B_M_27_resized
#   60 frames → 1 clips (0 frames discarded)
# [295/5672] no-fall/bed/nf_raw_b_3/B_M_78
#   30 frames → 0 clips (30 frames discarded)
# [296/5672] no-fall/bed/nf_raw_b_3/B_M_123
#   149 frames → 2 clips (29 frames discarded)
# [297/5672] no-fall/bed/nf_raw_b_3/B_M_101
#   180 frames → 3 clips (0 frames discarded)
# [298/5672] no-fall/bed/nf_raw_b_3/B_M_182
#   120 frames → 2 clips (0 frames discarded)
# [299/5672] no-fall/bed/nf_raw_b_3/B_M_162
#   120 frames → 2 clips (0 frames discarded)
# [300/5672] no-fall/bed/nf_raw_b_3/B_M_212_resized
#   180 frames → 3 clips (0 frames discarded)
#
# --- Progress: 300/5672 ---
#     Clips created so far: 402
#
# [301/5672] no-fall/bed/nf_raw_b_3/B_M_19_resized
#   90 frames → 1 clips (30 frames discarded)
# [302/5672] no-fall/bed/nf_raw_b_3/B_M_208
#   240 frames → 4 clips (0 frames discarded)
# [303/5672] no-fall/bed/nf_raw_b_3/B_M_115
#   180 frames → 3 clips (0 frames discarded)
# [304/5672] no-fall/bed/nf_raw_b_3/B_M_48
#   180 frames → 3 clips (0 frames discarded)
# [305/5672] no-fall/bed/nf_raw_b_3/B_M_145
#   150 frames → 2 clips (30 frames discarded)
# [306/5672] no-fall/bed/nf_raw_b_3/B_M_206
#   30 frames → 0 clips (30 frames discarded)
# [307/5672] no-fall/bed/nf_raw_b_3/B_M_119
#   150 frames → 2 clips (30 frames discarded)
# [308/5672] no-fall/bed/nf_raw_b_3/B_M_67
#   90 frames → 1 clips (30 frames discarded)
# [309/5672] no-fall/bed/nf_raw_b_3/B_M_186_resized
#   150 frames → 2 clips (30 frames discarded)
# [310/5672] no-fall/bed/nf_raw_b_3/B_M_63
#   180 frames → 3 clips (0 frames discarded)
# [311/5672] no-fall/bed/nf_raw_b_3/B_M_135_resized
#   90 frames → 1 clips (30 frames discarded)
# [312/5672] no-fall/bed/nf_raw_b_3/B_M_43_resized
#   90 frames → 1 clips (30 frames discarded)
# [313/5672] no-fall/bed/nf_raw_b_3/B_M_103
#   180 frames → 3 clips (0 frames discarded)
# [314/5672] no-fall/bed/nf_raw_b_3/B_M_125
#   149 frames → 2 clips (29 frames discarded)
# [315/5672] no-fall/bed/nf_raw_b_3/B_M_60
#   150 frames → 2 clips (30 frames discarded)
# [316/5672] no-fall/bed/nf_raw_b_3/B_M_179
#   120 frames → 2 clips (0 frames discarded)
# [317/5672] no-fall/bed/nf_raw_b_3/B_M_20_resized
#   60 frames → 1 clips (0 frames discarded)
# [318/5672] no-fall/bed/nf_raw_b_3/B_M_08
#   120 frames → 2 clips (0 frames discarded)
# [319/5672] no-fall/bed/nf_raw_b_3/B_M_80
#   30 frames → 0 clips (30 frames discarded)
# [320/5672] no-fall/bed/nf_raw_b_3/B_M_155
#   120 frames → 2 clips (0 frames discarded)
# [321/5672] no-fall/bed/nf_raw_b_3/B_M_85
#   210 frames → 3 clips (30 frames discarded)
# [322/5672] no-fall/bed/nf_raw_b_3/B_M_69
#   60 frames → 1 clips (0 frames discarded)
# [323/5672] no-fall/bed/nf_raw_b_3/B_M_26_resized
#   90 frames → 1 clips (30 frames discarded)
# [324/5672] no-fall/bed/nf_raw_b_3/B_M_74
#   60 frames → 1 clips (0 frames discarded)
# [325/5672] no-fall/bed/nf_raw_b_3/B_M_54
#   180 frames → 3 clips (0 frames discarded)
# [326/5672] no-fall/bed/nf_raw_b_3/B_M_209
#   210 frames → 3 clips (30 frames discarded)
# [327/5672] no-fall/bed/nf_raw_b_3/B_M_113
#   180 frames → 3 clips (0 frames discarded)
# [328/5672] no-fall/bed/nf_raw_b_3/B_M_13
#   90 frames → 1 clips (30 frames discarded)
# [329/5672] no-fall/bed/nf_raw_b_3/B_M_100
#   150 frames → 2 clips (30 frames discarded)
# [330/5672] no-fall/bed/nf_raw_b_3/B_M_30_resized
#   90 frames → 1 clips (30 frames discarded)
# [331/5672] no-fall/bed/nf_raw_b_3/B_M_41
#   90 frames → 1 clips (30 frames discarded)
# [332/5672] no-fall/bed/nf_raw_b_3/B_M_207
#   180 frames → 3 clips (0 frames discarded)
# [333/5672] no-fall/bed/nf_raw_b_3/B_M_121
#   120 frames → 2 clips (0 frames discarded)
# [334/5672] no-fall/bed/nf_raw_b_3/B_M_22_resized
#   120 frames → 2 clips (0 frames discarded)
# [335/5672] no-fall/bed/nf_raw_b_3/B_M_139
#   120 frames → 2 clips (0 frames discarded)
# [336/5672] no-fall/bed/nf_raw_b_3/B_M_107
#   150 frames → 2 clips (30 frames discarded)
# [337/5672] no-fall/bed/nf_raw_b_3/B_M_161
#   120 frames → 2 clips (0 frames discarded)
# [338/5672] no-fall/bed/nf_raw_b_3/B_M_31_resized
#   90 frames → 1 clips (30 frames discarded)
# [339/5672] no-fall/bed/nf_raw_b_3/B_M_174
#   120 frames → 2 clips (0 frames discarded)
# [340/5672] no-fall/bed/nf_raw_b_3/B_M_152
#   90 frames → 1 clips (30 frames discarded)
# [341/5672] no-fall/bed/nf_raw_b_3/B_M_87_resized
#   180 frames → 3 clips (0 frames discarded)
# [342/5672] no-fall/bed/nf_raw_b_3/B_M_213
#   150 frames → 2 clips (30 frames discarded)
# [343/5672] no-fall/bed/nf_raw_b_3/B_M_40
#   120 frames → 2 clips (0 frames discarded)
# [344/5672] no-fall/bed/nf_raw_b_3/B_M_93
#   210 frames → 3 clips (30 frames discarded)
# [345/5672] no-fall/bed/nf_raw_b_3/B_M_190
#   60 frames → 1 clips (0 frames discarded)
# [346/5672] no-fall/bed/nf_raw_b_3/B_M_04_resized
#   120 frames → 2 clips (0 frames discarded)
# [347/5672] no-fall/bed/nf_raw_b_3/B_M_14
#   90 frames → 1 clips (30 frames discarded)
# [348/5672] no-fall/bed/nf_raw_b_3/B_M_110
#   150 frames → 2 clips (30 frames discarded)
# [349/5672] no-fall/bed/nf_raw_b_3/B_M_160
#   120 frames → 2 clips (0 frames discarded)
# [350/5672] no-fall/bed/nf_raw_b_3/B_M_49
#   180 frames → 3 clips (0 frames discarded)
# [351/5672] no-fall/bed/nf_raw_b_3/B_M_92
#   150 frames → 2 clips (30 frames discarded)
# [352/5672] no-fall/bed/nf_raw_b_3/B_M_138
#   90 frames → 1 clips (30 frames discarded)
# [353/5672] no-fall/bed/nf_raw_b_3/B_M_137
#   30 frames → 0 clips (30 frames discarded)
# [354/5672] no-fall/bed/nf_raw_b_3/B_M_133_resized
#   90 frames → 1 clips (30 frames discarded)
# [355/5672] no-fall/bed/nf_raw_b_3/B_M_198_resized
#   30 frames → 0 clips (30 frames discarded)
# [356/5672] no-fall/bed/nf_raw_b_3/B_M_167_resized
#   150 frames → 2 clips (30 frames discarded)
# [357/5672] no-fall/bed/nf_raw_b_3/B_M_196
#   60 frames → 1 clips (0 frames discarded)
# [358/5672] no-fall/bed/nf_raw_b_3/B_M_173
#   120 frames → 2 clips (0 frames discarded)
# [359/5672] no-fall/bed/nf_raw_b_3/B_M_122
#   149 frames → 2 clips (29 frames discarded)
# [360/5672] no-fall/bed/nf_raw_b_3/B_M_28_resized
#   90 frames → 1 clips (30 frames discarded)
# [361/5672] no-fall/bed/nf_raw_b_3/B_M_153
#   90 frames → 1 clips (30 frames discarded)
# [362/5672] no-fall/bed/nf_raw_b_3/B_M_150
#   150 frames → 2 clips (30 frames discarded)
# [363/5672] no-fall/bed/nf_raw_b_3/B_M_57
#   150 frames → 2 clips (30 frames discarded)
# [364/5672] no-fall/bed/nf_raw_b_3/B_M_53
#   180 frames → 3 clips (0 frames discarded)
# [365/5672] no-fall/bed/nf_raw_b_3/B_M_176
#   120 frames → 2 clips (0 frames discarded)
# [366/5672] no-fall/bed/nf_raw_b_3/B_M_06
#   120 frames → 2 clips (0 frames discarded)
# [367/5672] no-fall/bed/nf_raw_b_3/B_M_62
#   150 frames → 2 clips (30 frames discarded)
# [368/5672] no-fall/bed/nf_raw_b_3/B_M_76
#   30 frames → 0 clips (30 frames discarded)
# [369/5672] no-fall/bed/nf_raw_b_3/B_M_180
#   120 frames → 2 clips (0 frames discarded)
# [370/5672] no-fall/bed/nf_raw_b_3/B_M_61
#   150 frames → 2 clips (30 frames discarded)
# [371/5672] no-fall/bed/nf_raw_b_3/B_M_168
#   120 frames → 2 clips (0 frames discarded)
# [372/5672] no-fall/bed/nf_raw_b_3/B_M_117
#   120 frames → 2 clips (0 frames discarded)
# [373/5672] no-fall/bed/nf_raw_b_3/B_M_159
#   120 frames → 2 clips (0 frames discarded)
# [374/5672] no-fall/bed/nf_raw_b_3/B_M_17_resized
#   90 frames → 1 clips (30 frames discarded)
# [375/5672] no-fall/bed/nf_raw_b_3/B_M_170
#   120 frames → 2 clips (0 frames discarded)
# [376/5672] no-fall/bed/nf_raw_b_3/B_M_36
#   90 frames → 1 clips (30 frames discarded)
# [377/5672] no-fall/bed/nf_raw_b_3/B_M_91_resized
#   210 frames → 3 clips (30 frames discarded)
# [378/5672] no-fall/bed/nf_raw_b_3/B_M_146
#   120 frames → 2 clips (0 frames discarded)
# [379/5672] no-fall/bed/nf_raw_b_3/B_M_185_resized
#   150 frames → 2 clips (30 frames discarded)
# [380/5672] no-fall/bed/nf_raw_b_3/B_M_29_resized
#   90 frames → 1 clips (30 frames discarded)
# [381/5672] no-fall/bed/nf_raw_b_3/B_M_05
#   150 frames → 2 clips (30 frames discarded)
# [382/5672] no-fall/bed/nf_raw_b_3/B_M_215
#   150 frames → 2 clips (30 frames discarded)
# [383/5672] no-fall/bed/nf_raw_b_3/B_M_118
#   120 frames → 2 clips (0 frames discarded)
# [384/5672] no-fall/bed/nf_raw_b_3/B_M_82
#   30 frames → 0 clips (30 frames discarded)
# [385/5672] no-fall/bed/nf_raw_b_3/B_M_148
#   120 frames → 2 clips (0 frames discarded)
# [386/5672] no-fall/bed/nf_raw_b_3/B_M_211
#   210 frames → 3 clips (30 frames discarded)
# [387/5672] no-fall/bed/nf_raw_b_3/B_M_52
#   120 frames → 2 clips (0 frames discarded)
# [388/5672] no-fall/bed/nf_raw_b_3/B_M_83
#   30 frames → 0 clips (30 frames discarded)
# [389/5672] no-fall/bed/nf_raw_b_3/B_M_166
#   150 frames → 2 clips (30 frames discarded)
# [390/5672] no-fall/bed/nf_raw_b_3/B_M_90_resized
#   150 frames → 2 clips (30 frames discarded)
# [391/5672] no-fall/bed/nf_raw_b_3/B_M_204
#   30 frames → 0 clips (30 frames discarded)
# [392/5672] no-fall/bed/nf_raw_b_3/B_M_79
#   60 frames → 1 clips (0 frames discarded)
# [393/5672] no-fall/bed/nf_raw_b_3/B_M_181
#   120 frames → 2 clips (0 frames discarded)
# [394/5672] no-fall/bed/nf_raw_b_3/B_M_94
#   150 frames → 2 clips (30 frames discarded)
# [395/5672] no-fall/bed/nf_raw_b_3/B_M_188
#   60 frames → 1 clips (0 frames discarded)
# [396/5672] no-fall/bed/nf_raw_b_3/B_M_09
#   120 frames → 2 clips (0 frames discarded)
# [397/5672] no-fall/bed/nf_raw_b_3/B_M_46
#   150 frames → 2 clips (30 frames discarded)
# [398/5672] no-fall/bed/nf_raw_b_3/B_M_97
#   150 frames → 2 clips (30 frames discarded)
# [399/5672] no-fall/bed/nf_raw_b_3/B_M_130_resized
#   90 frames → 1 clips (30 frames discarded)
# [400/5672] no-fall/bed/nf_raw_b_3/B_M_64
#   90 frames → 1 clips (30 frames discarded)
#
# --- Progress: 400/5672 ---
#     Clips created so far: 576
#
# [401/5672] no-fall/bed/nf_raw_b_3/B_M_184_resized
#   150 frames → 2 clips (30 frames discarded)
# [402/5672] no-fall/bed/nf_raw_b_3/B_M_81
#   60 frames → 1 clips (0 frames discarded)
# [403/5672] no-fall/bed/nf_raw_b_3/B_M_141
#   90 frames → 1 clips (30 frames discarded)
# [404/5672] no-fall/bed/nf_raw_b_3/B_M_68
#   30 frames → 0 clips (30 frames discarded)
# [405/5672] no-fall/bed/nf_raw_b_3/B_M_96
#   180 frames → 3 clips (0 frames discarded)
# [406/5672] no-fall/bed/nf_raw_b_3/B_M_158
#   120 frames → 2 clips (0 frames discarded)
# [407/5672] no-fall/bed/nf_raw_b_3/B_M_01_resized
#   120 frames → 2 clips (0 frames discarded)
# [408/5672] no-fall/bed/nf_raw_b_3/B_M_105
#   150 frames → 2 clips (30 frames discarded)
# [409/5672] no-fall/bed/nf_raw_b_3/B_M_71
#   30 frames → 0 clips (30 frames discarded)
# [410/5672] no-fall/bed/nf_raw_b_3/B_M_11
#   120 frames → 2 clips (0 frames discarded)
# [411/5672] no-fall/bed/nf_raw_b_3/B_M_140
#   90 frames → 1 clips (30 frames discarded)
# [412/5672] no-fall/bed/nf_raw_b_3/B_M_104
#   150 frames → 2 clips (30 frames discarded)
# [413/5672] no-fall/bed/nf_raw_b_3/B_M_32_resized
#   60 frames → 1 clips (0 frames discarded)
# [414/5672] no-fall/bed/nf_raw_b_3/B_M_163
#   120 frames → 2 clips (0 frames discarded)
# [415/5672] no-fall/bed/nf_raw_b_3/B_M_75
#   30 frames → 0 clips (30 frames discarded)
# [416/5672] no-fall/bed/nf_raw_b_3/B_M_143
#   150 frames → 2 clips (30 frames discarded)
# [417/5672] no-fall/bed/nf_raw_b_3/B_M_07_resized
#   90 frames → 1 clips (30 frames discarded)
# [418/5672] no-fall/bed/nf_raw_b_3/B_M_111
#   120 frames → 2 clips (0 frames discarded)
# [419/5672] no-fall/bed/nf_raw_b_3/B_M_66
#   60 frames → 1 clips (0 frames discarded)
# [420/5672] no-fall/bed/nf_raw_b_3/B_M_128_resized
#   60 frames → 1 clips (0 frames discarded)
# [421/5672] no-fall/bed/nf_raw_b_3/B_M_44
#   90 frames → 1 clips (30 frames discarded)
# [422/5672] no-fall/bed/nf_raw_b_3/B_M_58
#   120 frames → 2 clips (0 frames discarded)
# [423/5672] no-fall/bed/nf_raw_b_3/B_M_210
#   150 frames → 2 clips (30 frames discarded)
# [424/5672] no-fall/bed/nf_raw_b_3/B_M_214
#   150 frames → 2 clips (30 frames discarded)
# [425/5672] no-fall/bed/nf_raw_b_3/B_M_15
#   90 frames → 1 clips (30 frames discarded)
# [426/5672] no-fall/bed/nf_raw_b_3/B_M_102
#   150 frames → 2 clips (30 frames discarded)
# [427/5672] no-fall/bed/nf_raw_b_3/B_M_39
#   150 frames → 2 clips (30 frames discarded)
# [428/5672] no-fall/bed/nf_raw_b_3/B_M_126
#   149 frames → 2 clips (29 frames discarded)
# [429/5672] no-fall/bed/nf_raw_b_3/B_M_127_resized
#   90 frames → 1 clips (30 frames discarded)
# [430/5672] no-fall/bed/nf_raw_b_3/B_M_114
#   180 frames → 3 clips (0 frames discarded)
# [431/5672] no-fall/bed/nf_raw_b_3/B_M_50
#   180 frames → 3 clips (0 frames discarded)
# [432/5672] no-fall/bed/nf_raw_b_3/B_M_70
#   30 frames → 0 clips (30 frames discarded)
# [433/5672] no-fall/bed/nf_raw_b_3/B_M_149
#   120 frames → 2 clips (0 frames discarded)
# [434/5672] no-fall/bed/nf_raw_b_3/B_M_23_resized
#   120 frames → 2 clips (0 frames discarded)
# [435/5672] no-fall/bed/nf_raw_b_3/B_M_33
#   90 frames → 1 clips (30 frames discarded)
# [436/5672] no-fall/bed/nf_raw_b_3/B_M_131_resized
#   90 frames → 1 clips (30 frames discarded)
# [437/5672] no-fall/bed/nf_raw_b_3/B_M_21_resized
#   90 frames → 1 clips (30 frames discarded)
# [438/5672] no-fall/bed/nf_raw_b_3/B_M_178
#   120 frames → 2 clips (0 frames discarded)
# [439/5672] no-fall/bed/nf_raw_b_3/B_M_116
#   150 frames → 2 clips (30 frames discarded)
# [440/5672] no-fall/bed/nf_raw_b_3/B_M_77
#   30 frames → 0 clips (30 frames discarded)
# [441/5672] no-fall/bed/nf_raw_b_3/B_M_10
#   120 frames → 2 clips (0 frames discarded)
# [442/5672] no-fall/bed/nf_raw_b_3/B_M_164
#   120 frames → 2 clips (0 frames discarded)
# [443/5672] no-fall/bed/nf_raw_b_3/B_M_72
#   60 frames → 1 clips (0 frames discarded)
# [444/5672] no-fall/bed/nf_raw_b_3/B_M_56
#   150 frames → 2 clips (30 frames discarded)
# [445/5672] no-fall/bed/nf_raw_b_3/B_M_124
#   149 frames → 2 clips (29 frames discarded)
# [446/5672] no-fall/bed/nf_raw_b_3/B_M_144
#   120 frames → 2 clips (0 frames discarded)
# [447/5672] no-fall/bed/nf_raw_b_3/B_M_147
#   90 frames → 1 clips (30 frames discarded)
# [448/5672] no-fall/bed/nf_raw_b_3/B_M_37
#   60 frames → 1 clips (0 frames discarded)
# [449/5672] no-fall/bed/nf_raw_b_3/B_M_156
#   120 frames → 2 clips (0 frames discarded)
# [450/5672] no-fall/bed/nf_raw_b_3/B_M_59
#   180 frames → 3 clips (0 frames discarded)
# [451/5672] no-fall/bed/nf_raw_b_3/B_M_18_resized
#   60 frames → 1 clips (0 frames discarded)
# [452/5672] no-fall/bed/nf_raw_b_3/B_M_142
#   150 frames → 2 clips (30 frames discarded)
# [453/5672] no-fall/bed/nf_raw_b_3/B_M_89_resized
#   150 frames → 2 clips (30 frames discarded)
# [454/5672] no-fall/bed/nf_raw_b_3/B_M_73
#   30 frames → 0 clips (30 frames discarded)
# [455/5672] no-fall/bed/nf_raw_b_3/B_M_154
#   90 frames → 1 clips (30 frames discarded)
# [456/5672] no-fall/bed/nf_raw_b_3/B_M_45
#   60 frames → 1 clips (0 frames discarded)
# [457/5672] no-fall/bed/nf_raw_b_3/B_M_38
#   120 frames → 2 clips (0 frames discarded)
# [458/5672] no-fall/bed/nf_raw_b_3/B_M_24_resized
#   120 frames → 2 clips (0 frames discarded)
# [459/5672] no-fall/bed/nf_raw_b_3/B_M_88_resized
#   210 frames → 3 clips (30 frames discarded)
# [460/5672] no-fall/bed/nf_raw_b_3/B_M_172
#   120 frames → 2 clips (0 frames discarded)
# [461/5672] no-fall/bed/nf_raw_b_3/B_M_25_resized
#   90 frames → 1 clips (30 frames discarded)
# [462/5672] no-fall/bed/nf_raw_b_3/B_M_169
#   120 frames → 2 clips (0 frames discarded)
# [463/5672] no-fall/bed/nf_raw_b_3/B_M_151
#   120 frames → 2 clips (0 frames discarded)
# [464/5672] no-fall/bed/nf_raw_b_3/B_M_65
#   60 frames → 1 clips (0 frames discarded)
# [465/5672] no-fall/bed/nf_raw_b_3/B_M_157
#   120 frames → 2 clips (0 frames discarded)
# [466/5672] no-fall/bed/nf_raw_b_3/B_M_109
#   150 frames → 2 clips (30 frames discarded)
# [467/5672] no-fall/bed/nf_raw_b_3/B_M_129_resized
#   120 frames → 2 clips (0 frames discarded)
# [468/5672] no-fall/bed/nf_raw_b_3/B_M_42
#   120 frames → 2 clips (0 frames discarded)
# [469/5672] no-fall/bed/nf_raw_b_3/B_M_34
#   90 frames → 1 clips (30 frames discarded)
# [470/5672] no-fall/bed/nf_raw_b_3/B_M_03
#   150 frames → 2 clips (30 frames discarded)
# [471/5672] no-fall/bed/nf_raw_b_3/B_M_171
#   120 frames → 2 clips (0 frames discarded)
# [472/5672] no-fall/bed/nf_raw_b_3/B_M_112
#   180 frames → 3 clips (0 frames discarded)
# [473/5672] no-fall/bed/nf_raw_b_3/B_M_177
#   150 frames → 2 clips (30 frames discarded)
# [474/5672] no-fall/bed/nf_raw_b_3/B_M_136_resized
#   90 frames → 1 clips (30 frames discarded)
# [475/5672] no-fall/bed/nf_raw_b_3/B_M_47
#   180 frames → 3 clips (0 frames discarded)
# [476/5672] no-fall/bed/nf_raw_b_3/B_M_202
#   30 frames → 0 clips (30 frames discarded)
# [477/5672] no-fall/bed/nf_raw_b_3/B_M_02_resized
#   90 frames → 1 clips (30 frames discarded)
# [478/5672] no-fall/bed/nf_raw_b_3/B_M_132_resized
#   120 frames → 2 clips (0 frames discarded)
# [479/5672] no-fall/bed/nf_raw_b_3/B_M_106
#   180 frames → 3 clips (0 frames discarded)
# [480/5672] no-fall/bed/nf_raw_b_3/B_M_99
#   150 frames → 2 clips (30 frames discarded)
# [481/5672] no-fall/bed/nf_raw_b_3/B_M_55
#   150 frames → 2 clips (30 frames discarded)
# [482/5672] no-fall/bed/nf_raw_b_3/B_M_51
#   180 frames → 3 clips (0 frames discarded)
# [483/5672] no-fall/bed/nf_raw_b_3/B_M_16_resized
#   90 frames → 1 clips (30 frames discarded)
# [484/5672] no-fall/bed/nf_raw_b_3/B_M_35
#   90 frames → 1 clips (30 frames discarded)
# [485/5672] no-fall/bed/nf_raw_b_3/B_M_95
#   150 frames → 2 clips (30 frames discarded)
# [486/5672] no-fall/bed/nf_raw_b_3/B_M_12
#   90 frames → 1 clips (30 frames discarded)
# [487/5672] no-fall/bed/nf_raw_b_3/B_M_108
#   120 frames → 2 clips (0 frames discarded)
# [488/5672] no-fall/bed/nf_raw_b_3/B_M_120
#   150 frames → 2 clips (30 frames discarded)
# [489/5672] no-fall/bed/nf_raw_b_3/B_M_183_resized
#   150 frames → 2 clips (30 frames discarded)
# [490/5672] no-fall/bed/nf_raw_b_1/B_N_375
#   179 frames → 2 clips (59 frames discarded)
# [491/5672] no-fall/bed/nf_raw_b_1/B_N_464_resized
#   120 frames → 2 clips (0 frames discarded)
# [492/5672] no-fall/bed/nf_raw_b_1/B_N_235
#   120 frames → 2 clips (0 frames discarded)
# [493/5672] no-fall/bed/nf_raw_b_1/B_N_186
#   90 frames → 1 clips (30 frames discarded)
# [494/5672] no-fall/bed/nf_raw_b_1/B_N_531
#   120 frames → 2 clips (0 frames discarded)
# [495/5672] no-fall/bed/nf_raw_b_1/B_N_463_resized
#   120 frames → 2 clips (0 frames discarded)
# [496/5672] no-fall/bed/nf_raw_b_1/B_N_478_resized
#   150 frames → 2 clips (30 frames discarded)
# [497/5672] no-fall/bed/nf_raw_b_1/B_N_407
#   120 frames → 2 clips (0 frames discarded)
# [498/5672] no-fall/bed/nf_raw_b_1/B_N_123
#   90 frames → 1 clips (30 frames discarded)
# [499/5672] no-fall/bed/nf_raw_b_1/B_N_159_resized
#   120 frames → 2 clips (0 frames discarded)
# [500/5672] no-fall/bed/nf_raw_b_1/B_N_209
#   60 frames → 1 clips (0 frames discarded)
#
# --- Progress: 500/5672 ---
#     Clips created so far: 741
#
# [501/5672] no-fall/bed/nf_raw_b_1/B_N_327
#   270 frames → 4 clips (30 frames discarded)
# [502/5672] no-fall/bed/nf_raw_b_1/B_N_116
#   96 frames → 1 clips (36 frames discarded)
# [503/5672] no-fall/bed/nf_raw_b_1/B_N_170_resized
#   96 frames → 1 clips (36 frames discarded)
# [504/5672] no-fall/bed/nf_raw_b_1/B_N_523
#   120 frames → 2 clips (0 frames discarded)
# [505/5672] no-fall/bed/nf_raw_b_1/B_N_257
#   60 frames → 1 clips (0 frames discarded)
# [506/5672] no-fall/bed/nf_raw_b_1/B_N_268_resized
#   90 frames → 1 clips (30 frames discarded)
# [507/5672] no-fall/bed/nf_raw_b_1/B_N_211
#   60 frames → 1 clips (0 frames discarded)
# [508/5672] no-fall/bed/nf_raw_b_1/B_N_262_resized
#   120 frames → 2 clips (0 frames discarded)
# [509/5672] no-fall/bed/nf_raw_b_1/B_N_432_resized
#   120 frames → 2 clips (0 frames discarded)
# [510/5672] no-fall/bed/nf_raw_b_1/B_N_355
#   90 frames → 1 clips (30 frames discarded)
# [511/5672] no-fall/bed/nf_raw_b_1/B_N_158_resized
#   72 frames → 1 clips (12 frames discarded)
# [512/5672] no-fall/bed/nf_raw_b_1/B_N_385
#   149 frames → 2 clips (29 frames discarded)
# [513/5672] no-fall/bed/nf_raw_b_1/B_N_511
#   90 frames → 1 clips (30 frames discarded)
# [514/5672] no-fall/bed/nf_raw_b_1/B_N_293_resized
#   90 frames → 1 clips (30 frames discarded)
# [515/5672] no-fall/bed/nf_raw_b_1/B_N_271_resized
#   120 frames → 2 clips (0 frames discarded)
# [516/5672] no-fall/bed/nf_raw_b_1/B_N_364
#   120 frames → 2 clips (0 frames discarded)
# [517/5672] no-fall/bed/nf_raw_b_1/B_N_460_resized
#   120 frames → 2 clips (0 frames discarded)
# [518/5672] no-fall/bed/nf_raw_b_1/B_N_363
#   150 frames → 2 clips (30 frames discarded)
# [519/5672] no-fall/bed/nf_raw_b_1/B_N_313
#   200 frames → 3 clips (20 frames discarded)
# [520/5672] no-fall/bed/nf_raw_b_1/B_N_539
#   90 frames → 1 clips (30 frames discarded)
# [521/5672] no-fall/bed/nf_raw_b_1/B_N_325
#   300 frames → 5 clips (0 frames discarded)
# [522/5672] no-fall/bed/nf_raw_b_1/B_N_284_resized
#   60 frames → 1 clips (0 frames discarded)
# [523/5672] no-fall/bed/nf_raw_b_1/B_N_359
#   90 frames → 1 clips (30 frames discarded)
# [524/5672] no-fall/bed/nf_raw_b_1/B_N_290_resized
#   150 frames → 2 clips (30 frames discarded)
# [525/5672] no-fall/bed/nf_raw_b_1/B_N_352_resized
#   144 frames → 2 clips (24 frames discarded)
# [526/5672] no-fall/bed/nf_raw_b_1/B_N_528
#   90 frames → 1 clips (30 frames discarded)
# [527/5672] no-fall/bed/nf_raw_b_1/B_N_289_resized
#   120 frames → 2 clips (0 frames discarded)
# [528/5672] no-fall/bed/nf_raw_b_1/B_N_202
#   72 frames → 1 clips (12 frames discarded)
# [529/5672] no-fall/bed/nf_raw_b_1/B_N_169_resized
#   120 frames → 2 clips (0 frames discarded)
# [530/5672] no-fall/bed/nf_raw_b_1/B_N_404_resized
#   120 frames → 2 clips (0 frames discarded)
# [531/5672] no-fall/bed/nf_raw_b_1/B_N_366
#   120 frames → 2 clips (0 frames discarded)
# [532/5672] no-fall/bed/nf_raw_b_1/B_N_466_resized
#   119 frames → 1 clips (59 frames discarded)
# [533/5672] no-fall/bed/nf_raw_b_1/B_N_287_resized
#   119 frames → 1 clips (59 frames discarded)
# [534/5672] no-fall/bed/nf_raw_b_1/B_N_409
#   120 frames → 2 clips (0 frames discarded)
# [535/5672] no-fall/bed/nf_raw_b_1/B_N_382
#   149 frames → 2 clips (29 frames discarded)
# [536/5672] no-fall/bed/nf_raw_b_1/B_N_220
#   119 frames → 1 clips (59 frames discarded)
# [537/5672] no-fall/bed/nf_raw_b_1/B_N_239
#   120 frames → 2 clips (0 frames discarded)
# [538/5672] no-fall/bed/nf_raw_b_1/B_N_431
#   240 frames → 4 clips (0 frames discarded)
# [539/5672] no-fall/bed/nf_raw_b_1/B_N_316
#   270 frames → 4 clips (30 frames discarded)
# [540/5672] no-fall/bed/nf_raw_b_1/B_N_344_resized
#   144 frames → 2 clips (24 frames discarded)
# [541/5672] no-fall/bed/nf_raw_b_1/B_N_386
#   149 frames → 2 clips (29 frames discarded)
# [542/5672] no-fall/bed/nf_raw_b_1/B_N_381
# ...
#   75 frames → 1 clips (15 frames discarded)
#
# --- Progress: 5500/5672 ---
#     Clips created so far: 6898
#
# [5501/5672] fall/stand/f_raw_s_1/S_D_0070
#   120 frames → 2 clips (0 frames discarded)
# [5502/5672] fall/stand/f_raw_s_1/S_D_0173
#   120 frames → 2 clips (0 frames discarded)
# [5503/5672] fall/stand/f_raw_s_1/S_D_0131
#   120 frames → 2 clips (0 frames discarded)
# [5504/5672] fall/stand/f_raw_s_1/S_D_0209
#   150 frames → 2 clips (30 frames discarded)
# [5505/5672] fall/stand/f_raw_s_1/S_D_0040_resized
#   72 frames → 1 clips (12 frames discarded)
# [5506/5672] fall/stand/f_raw_s_1/S_D_0126
#   120 frames → 2 clips (0 frames discarded)
# [5507/5672] fall/stand/f_raw_s_1/S_D_0086_resized
#   119 frames → 1 clips (59 frames discarded)
# [5508/5672] fall/stand/f_raw_s_1/S_D_0235_resized
#   120 frames → 2 clips (0 frames discarded)
# [5509/5672] fall/stand/f_raw_s_1/S_D_0162_resized
#   150 frames → 2 clips (30 frames discarded)
# [5510/5672] fall/stand/f_raw_s_1/S_D_0201
#   120 frames → 2 clips (0 frames discarded)
# [5511/5672] fall/stand/f_raw_s_1/S_D_0139_resized
#   120 frames → 2 clips (0 frames discarded)
# [5512/5672] fall/stand/f_raw_s_1/S_D_0165_resized
#   120 frames → 2 clips (0 frames discarded)
# [5513/5672] fall/stand/f_raw_s_1/S_D_0140_resized
#   150 frames → 2 clips (30 frames discarded)
# [5514/5672] fall/stand/f_raw_s_1/S_D_0114
#   120 frames → 2 clips (0 frames discarded)
# [5515/5672] fall/stand/f_raw_s_1/S_D_0257
#   180 frames → 3 clips (0 frames discarded)
# [5516/5672] fall/stand/f_raw_s_1/S_D_0083_resized
#   90 frames → 1 clips (30 frames discarded)
# [5517/5672] fall/stand/f_raw_s_1/S_D_0121
#   120 frames → 2 clips (0 frames discarded)
# [5518/5672] fall/stand/f_raw_s_1/S_D_0006
#   90 frames → 1 clips (30 frames discarded)
# [5519/5672] fall/stand/f_raw_s_1/S_D_0090_resized
#   119 frames → 1 clips (59 frames discarded)
# [5520/5672] fall/stand/f_raw_s_1/S_D_0200
#   120 frames → 2 clips (0 frames discarded)
# [5521/5672] fall/stand/f_raw_s_1/S_D_0180
#   120 frames → 2 clips (0 frames discarded)
# [5522/5672] fall/stand/f_raw_s_1/S_D_0137_resized
#   120 frames → 2 clips (0 frames discarded)
# [5523/5672] fall/stand/f_raw_s_1/S_D_0046
#   90 frames → 1 clips (30 frames discarded)
# [5524/5672] fall/stand/f_raw_s_1/S_D_0029
#   150 frames → 2 clips (30 frames discarded)
# [5525/5672] fall/stand/f_raw_s_1/S_D_0079_resized
#   119 frames → 1 clips (59 frames discarded)
# [5526/5672] fall/stand/f_raw_s_1/S_D_0108_resized
#   150 frames → 2 clips (30 frames discarded)
# [5527/5672] fall/stand/f_raw_s_1/S_D_0149_resized
#   120 frames → 2 clips (0 frames discarded)
# [5528/5672] fall/stand/f_raw_s_1/S_D_0178
#   120 frames → 2 clips (0 frames discarded)
# [5529/5672] fall/stand/f_raw_s_1/S_D_0147_resized
#   150 frames → 2 clips (30 frames discarded)
# [5530/5672] fall/stand/f_raw_s_1/S_D_0115
#   180 frames → 3 clips (0 frames discarded)
# [5531/5672] fall/stand/f_raw_s_1/S_D_0222
#   120 frames → 2 clips (0 frames discarded)
# [5532/5672] fall/stand/f_raw_s_1/S_D_0184
#   150 frames → 2 clips (30 frames discarded)
# [5533/5672] fall/stand/f_raw_s_1/S_D_0144
#   120 frames → 2 clips (0 frames discarded)
# [5534/5672] fall/stand/f_raw_s_1/S_D_0099_resized
#   90 frames → 1 clips (30 frames discarded)
# [5535/5672] fall/stand/f_raw_s_1/S_D_0087
#   120 frames → 2 clips (0 frames discarded)
# [5536/5672] fall/stand/f_raw_s_1/S_D_0017
#   60 frames → 1 clips (0 frames discarded)
# [5537/5672] fall/stand/f_raw_s_1/S_D_0044
#   120 frames → 2 clips (0 frames discarded)
# [5538/5672] fall/stand/f_raw_s_1/S_D_0132
#   90 frames → 1 clips (30 frames discarded)
# [5539/5672] fall/stand/f_raw_s_1/S_D_0152_resized
#   150 frames → 2 clips (30 frames discarded)
# [5540/5672] fall/stand/f_raw_s_1/S_D_0057
#   120 frames → 2 clips (0 frames discarded)
# [5541/5672] fall/stand/f_raw_s_1/S_D_0100_resized
#   120 frames → 2 clips (0 frames discarded)
# [5542/5672] fall/stand/f_raw_s_1/S_D_0117
#   120 frames → 2 clips (0 frames discarded)
# [5543/5672] fall/stand/f_raw_s_1/S_D_0250
#   179 frames → 2 clips (59 frames discarded)
# [5544/5672] fall/stand/f_raw_s_1/S_D_0230_resized
#   120 frames → 2 clips (0 frames discarded)
# [5545/5672] fall/stand/f_raw_s_1/S_D_0258
#   150 frames → 2 clips (30 frames discarded)
# [5546/5672] fall/stand/f_raw_s_1/S_D_0130
#   120 frames → 2 clips (0 frames discarded)
# [5547/5672] fall/stand/f_raw_s_1/S_D_0179
#   120 frames → 2 clips (0 frames discarded)
# [5548/5672] fall/stand/f_raw_s_1/S_D_0084_resized
#   119 frames → 1 clips (59 frames discarded)
# [5549/5672] fall/stand/f_raw_s_1/S_D_0240_resized
#   120 frames → 2 clips (0 frames discarded)
# [5550/5672] fall/stand/f_raw_s_1/S_D_0061
#   120 frames → 2 clips (0 frames discarded)
# [5551/5672] fall/stand/f_raw_s_1/S_D_0211_resized
#   96 frames → 1 clips (36 frames discarded)
# [5552/5672] fall/stand/f_raw_s_1/S_D_0248
#   120 frames → 2 clips (0 frames discarded)
# [5553/5672] fall/stand/f_raw_s_1/S_D_0188
#   120 frames → 2 clips (0 frames discarded)
# [5554/5672] fall/stand/f_raw_s_1/S_D_0187_resized
#   96 frames → 1 clips (36 frames discarded)
# [5555/5672] fall/stand/f_raw_s_1/S_D_0060
#   150 frames → 2 clips (30 frames discarded)
# [5556/5672] fall/stand/f_raw_s_1/S_D_0093_resized
#   119 frames → 1 clips (59 frames discarded)
# [5557/5672] fall/stand/f_raw_s_1/S_D_0167_resized
#   150 frames → 2 clips (30 frames discarded)
# [5558/5672] fall/stand/f_raw_s_1/S_D_0101_resized
#   150 frames → 2 clips (30 frames discarded)
# [5559/5672] fall/stand/f_raw_s_1/S_D_0218
#   120 frames → 2 clips (0 frames discarded)
# [5560/5672] fall/stand/f_raw_s_1/S_D_0251
#   150 frames → 2 clips (30 frames discarded)
# [5561/5672] fall/stand/f_raw_s_1/S_D_0081_resized
#   119 frames → 1 clips (59 frames discarded)
# [5562/5672] fall/stand/f_raw_s_1/S_D_0233_resized
#   120 frames → 2 clips (0 frames discarded)
# [5563/5672] fall/stand/f_raw_s_1/S_D_0154_resized
#   150 frames → 2 clips (30 frames discarded)
# [5564/5672] fall/stand/f_raw_s_1/S_D_0102_resized
#   150 frames → 2 clips (30 frames discarded)
# [5565/5672] fall/stand/f_raw_s_1/S_D_0042
#   90 frames → 1 clips (30 frames discarded)
# [5566/5672] fall/stand/f_raw_s_1/S_D_0009
#   120 frames → 2 clips (0 frames discarded)
# [5567/5672] fall/stand/f_raw_s_1/S_D_0243
#   150 frames → 2 clips (30 frames discarded)
# [5568/5672] fall/stand/f_raw_s_1/S_D_0220
#   120 frames → 2 clips (0 frames discarded)
# [5569/5672] fall/stand/f_raw_s_1/S_D_0252
#   150 frames → 2 clips (30 frames discarded)
# [5570/5672] fall/stand/f_raw_s_1/S_D_0207
#   120 frames → 2 clips (0 frames discarded)
# [5571/5672] fall/stand/f_raw_s_1/S_D_0166
#   150 frames → 2 clips (30 frames discarded)
# [5572/5672] fall/stand/f_raw_s_1/S_D_0226
#   150 frames → 2 clips (30 frames discarded)
# [5573/5672] fall/stand/f_raw_s_1/S_D_0213
#   120 frames → 2 clips (0 frames discarded)
# [5574/5672] fall/stand/f_raw_s_1/S_D_0051
#   90 frames → 1 clips (30 frames discarded)
# [5575/5672] fall/stand/f_raw_s_1/S_D_0125
#   150 frames → 2 clips (30 frames discarded)
# [5576/5672] fall/stand/f_raw_s_1/S_D_0030_resized
#   89 frames → 1 clips (29 frames discarded)
# [5577/5672] fall/stand/f_raw_s_1/S_D_0212
#   120 frames → 2 clips (0 frames discarded)
# [5578/5672] fall/stand/f_raw_s_1/S_D_0157
#   120 frames → 2 clips (0 frames discarded)
# [5579/5672] fall/stand/f_raw_s_1/S_D_0217
#   120 frames → 2 clips (0 frames discarded)
# [5580/5672] fall/stand/f_raw_s_1/S_D_0192
#   120 frames → 2 clips (0 frames discarded)
# [5581/5672] fall/stand/f_raw_s_1/S_D_0197
#   120 frames → 2 clips (0 frames discarded)
# [5582/5672] fall/stand/f_raw_s_1/S_D_0028_resized
#   48 frames → 0 clips (48 frames discarded)
# [5583/5672] fall/stand/f_raw_s_1/S_D_0159
#   120 frames → 2 clips (0 frames discarded)
# [5584/5672] fall/stand/f_raw_s_1/S_D_0176
#   120 frames → 2 clips (0 frames discarded)
# [5585/5672] fall/stand/f_raw_s_1/S_D_0097_resized
#   119 frames → 1 clips (59 frames discarded)
# [5586/5672] fall/stand/f_raw_s_1/S_D_0105_resized
#   150 frames → 2 clips (30 frames discarded)
# [5587/5672] fall/stand/f_raw_s_1/S_D_0189
#   120 frames → 2 clips (0 frames discarded)
# [5588/5672] fall/stand/f_raw_s_1/S_D_0168
#   120 frames → 2 clips (0 frames discarded)
# [5589/5672] fall/stand/f_raw_s_1/S_D_0066
#   90 frames → 1 clips (30 frames discarded)
# [5590/5672] fall/stand/f_raw_s_1/S_D_0203
#   150 frames → 2 clips (30 frames discarded)
# [5591/5672] fall/stand/f_raw_s_1/S_D_0052_resized
#   72 frames → 1 clips (12 frames discarded)
# [5592/5672] fall/stand/f_raw_s_1/S_D_0129
#   120 frames → 2 clips (0 frames discarded)
# [5593/5672] fall/stand/f_raw_s_1/S_D_0122
#   150 frames → 2 clips (30 frames discarded)
# [5594/5672] fall/stand/f_raw_s_1/S_D_0185
#   150 frames → 2 clips (30 frames discarded)
# [5595/5672] fall/stand/f_raw_s_1/S_D_0039_resized
#   60 frames → 1 clips (0 frames discarded)
# [5596/5672] fall/stand/f_raw_s_1/S_D_0120_resized
#   96 frames → 1 clips (36 frames discarded)
# [5597/5672] fall/stand/f_raw_s_1/S_D_0246
#   150 frames → 2 clips (30 frames discarded)
# [5598/5672] fall/stand/f_raw_s_1/S_D_0223_resized
#   120 frames → 2 clips (0 frames discarded)
# [5599/5672] fall/stand/f_raw_s_1/S_D_0249
#   120 frames → 2 clips (0 frames discarded)
# [5600/5672] fall/stand/f_raw_s_1/S_D_0107_resized
#   120 frames → 2 clips (0 frames discarded)
#
# --- Progress: 5600/5672 ---
#     Clips created so far: 7075
#
# [5601/5672] fall/stand/f_raw_s_1/S_D_0224
#   90 frames → 1 clips (30 frames discarded)
# [5602/5672] fall/stand/f_raw_s_1/S_D_0063
#   120 frames → 2 clips (0 frames discarded)
# [5603/5672] fall/stand/f_raw_s_1/S_D_0196
#   120 frames → 2 clips (0 frames discarded)
# [5604/5672] fall/stand/f_raw_s_1/S_D_0069
#   120 frames → 2 clips (0 frames discarded)
# [5605/5672] fall/stand/f_raw_s_1/S_D_0034_resized
#   119 frames → 1 clips (59 frames discarded)
# [5606/5672] fall/stand/f_raw_s_1/S_D_0104_resized
#   120 frames → 2 clips (0 frames discarded)
# [5607/5672] fall/stand/f_raw_s_1/S_D_0095_resized
#   149 frames → 2 clips (29 frames discarded)
# [5608/5672] fall/stand/f_raw_s_1/S_D_0160
#   120 frames → 2 clips (0 frames discarded)
# [5609/5672] fall/stand/f_raw_s_1/S_D_0229_resized
#   120 frames → 2 clips (0 frames discarded)
# [5610/5672] fall/stand/f_raw_s_1/S_D_0219
#   150 frames → 2 clips (30 frames discarded)
# [5611/5672] fall/stand/f_raw_s_1/S_D_0128
#   120 frames → 2 clips (0 frames discarded)
# [5612/5672] fall/stand/f_raw_s_1/S_D_0210
#   120 frames → 2 clips (0 frames discarded)
# [5613/5672] fall/stand/f_raw_s_1/S_D_0174
#   120 frames → 2 clips (0 frames discarded)
# [5614/5672] fall/stand/f_raw_s_1/S_D_0007
#   90 frames → 1 clips (30 frames discarded)
# [5615/5672] fall/stand/f_raw_s_1/S_D_0111
#   150 frames → 2 clips (30 frames discarded)
# [5616/5672] fall/stand/f_raw_s_1/S_D_0190
#   120 frames → 2 clips (0 frames discarded)
# [5617/5672] fall/stand/f_raw_s_1/S_D_0091_resized
#   119 frames → 1 clips (59 frames discarded)
# [5618/5672] fall/stand/f_raw_s_1/S_D_0068
#   120 frames → 2 clips (0 frames discarded)
# [5619/5672] fall/stand/f_raw_s_1/S_D_0239_resized
#   120 frames → 2 clips (0 frames discarded)
# [5620/5672] fall/stand/f_raw_s_1/S_D_0255
#   120 frames → 2 clips (0 frames discarded)
# [5621/5672] fall/stand/f_raw_s_1/S_D_0221
#   120 frames → 2 clips (0 frames discarded)
# [5622/5672] fall/stand/f_raw_s_1/S_D_0198
#   150 frames → 2 clips (30 frames discarded)
# [5623/5672] fall/stand/f_raw_s_1/S_D_0078_resized
#   119 frames → 1 clips (59 frames discarded)
# [5624/5672] fall/stand/f_raw_s_1/S_D_0002_resized
#   96 frames → 1 clips (36 frames discarded)
# [5625/5672] fall/stand/f_raw_s_1/S_D_0182
#   120 frames → 2 clips (0 frames discarded)
# [5626/5672] fall/stand/f_raw_s_1/S_D_0237_resized
#   120 frames → 2 clips (0 frames discarded)
# [5627/5672] fall/stand/f_raw_s_1/S_D_0123
#   150 frames → 2 clips (30 frames discarded)
# [5628/5672] fall/stand/f_raw_s_1/S_D_0245
#   150 frames → 2 clips (30 frames discarded)
# [5629/5672] fall/stand/f_raw_s_1/S_D_0234_resized
#   150 frames → 2 clips (30 frames discarded)
# [5630/5672] fall/stand/f_raw_s_1/S_D_0247_resized
#   96 frames → 1 clips (36 frames discarded)
# [5631/5672] fall/stand/f_raw_s_1/S_D_0038_resized
#   119 frames → 1 clips (59 frames discarded)
# [5632/5672] fall/stand/f_raw_s_1/S_D_0106_resized
#   120 frames → 2 clips (0 frames discarded)
# [5633/5672] fall/stand/f_raw_s_1/S_D_0244
#   150 frames → 2 clips (30 frames discarded)
# [5634/5672] fall/stand/f_raw_s_1/S_D_0089_resized
#   119 frames → 1 clips (59 frames discarded)
# [5635/5672] fall/stand/f_raw_s_1/S_D_0256
#   150 frames → 2 clips (30 frames discarded)
# [5636/5672] fall/stand/f_raw_s_1/S_D_0202
#   150 frames → 2 clips (30 frames discarded)
# [5637/5672] fall/stand/f_raw_s_1/S_D_0010
#   120 frames → 2 clips (0 frames discarded)
# [5638/5672] fall/stand/f_raw_s_1/S_D_0058
#   90 frames → 1 clips (30 frames discarded)
# [5639/5672] fall/stand/f_raw_s_1/S_D_0214
#   120 frames → 2 clips (0 frames discarded)
# [5640/5672] fall/stand/f_raw_s_1/S_D_0016_resized
#   72 frames → 1 clips (12 frames discarded)
# [5641/5672] fall/stand/f_raw_s_1/S_D_0077_resized
#   90 frames → 1 clips (30 frames discarded)
# [5642/5672] fall/stand/f_raw_s_1/S_D_0124
#   150 frames → 2 clips (30 frames discarded)
# [5643/5672] fall/stand/f_raw_s_1/S_D_0164_resized
#   150 frames → 2 clips (30 frames discarded)
# [5644/5672] fall/stand/f_raw_s_1/S_D_0236
#   120 frames → 2 clips (0 frames discarded)
# [5645/5672] fall/stand/f_raw_s_1/S_D_0043
#   120 frames → 2 clips (0 frames discarded)
# [5646/5672] fall/stand/f_raw_s_1/S_D_0181
#   120 frames → 2 clips (0 frames discarded)
# [5647/5672] fall/stand/f_raw_s_1/S_D_0241_resized
#   150 frames → 2 clips (30 frames discarded)
# [5648/5672] fall/stand/f_raw_s_1/S_D_0138_resized
#   150 frames → 2 clips (30 frames discarded)
# [5649/5672] fall/stand/f_raw_s_1/S_D_0031_resized
#   89 frames → 1 clips (29 frames discarded)
# [5650/5672] fall/stand/f_raw_s_1/S_D_0062
#   120 frames → 2 clips (0 frames discarded)
# [5651/5672] fall/stand/f_raw_s_1/S_D_0024
#   86 frames → 1 clips (26 frames discarded)
# [5652/5672] fall/stand/f_raw_s_1/S_D_0143_resized
#   120 frames → 2 clips (0 frames discarded)
# [5653/5672] fall/stand/f_raw_s_1/S_D_0142_resized
#   120 frames → 2 clips (0 frames discarded)
# [5654/5672] fall/stand/f_raw_s_1/S_D_0141_resized
#   120 frames → 2 clips (0 frames discarded)
# [5655/5672] fall/stand/f_raw_s_1/S_D_0050
#   60 frames → 1 clips (0 frames discarded)
# [5656/5672] fall/stand/f_raw_s_1/S_D_0195
#   90 frames → 1 clips (30 frames discarded)
# [5657/5672] fall/stand/f_raw_s_1/S_D_0032_resized
#   60 frames → 1 clips (0 frames discarded)
# [5658/5672] fall/stand/f_raw_s_1/S_D_0103_resized
#   120 frames → 2 clips (0 frames discarded)
# [5659/5672] fall/stand/f_raw_s_1/S_D_0041
#   120 frames → 2 clips (0 frames discarded)
# [5660/5672] fall/stand/f_raw_s_1/S_D_0056
#   90 frames → 1 clips (30 frames discarded)
# [5661/5672] fall/stand/f_raw_s_1/S_D_0151_resized
#   120 frames → 2 clips (0 frames discarded)
# [5662/5672] fall/stand/f_raw_s_1/S_D_0242
#   120 frames → 2 clips (0 frames discarded)
# [5663/5672] fall/stand/f_raw_s_1/S_D_0225
#   120 frames → 2 clips (0 frames discarded)
# [5664/5672] fall/stand/f_raw_s_1/S_D_0206
#   120 frames → 2 clips (0 frames discarded)
# [5665/5672] fall/stand/f_raw_s_1/S_D_0161
#   120 frames → 2 clips (0 frames discarded)
# [5666/5672] fall/stand/f_raw_s_1/S_D_0170
#   120 frames → 2 clips (0 frames discarded)
# [5667/5672] fall/stand/f_raw_s_1/S_D_0171
#   120 frames → 2 clips (0 frames discarded)
# [5668/5672] fall/stand/f_raw_s_1/S_D_0133
#   120 frames → 2 clips (0 frames discarded)
# [5669/5672] fall/stand/f_raw_s_1/S_D_0094_resized
#   119 frames → 1 clips (59 frames discarded)
# [5670/5672] fall/stand/f_raw_s_1/S_D_0045
#   60 frames → 1 clips (0 frames discarded)
# [5671/5672] fall/stand/f_raw_s_1/S_D_0076
#   120 frames → 2 clips (0 frames discarded)
# [5672/5672] fall/stand/f_raw_s_1/S_D_0047
#   60 frames → 1 clips (0 frames discarded)
#
# ======================================================================
# SEGMENTATION COMPLETE
# ======================================================================
# Total videos processed: 5672
# Total clips created: 7198
# Average clips per video: 1.3
#
# Frame usage:
#   Total frames: 532733
#   Frames in clips: 431880
#   Frames discarded: 100853 (18.9%)
#
# Metadata saved to: data/segmented_clips/clips_metadata.json
# Clips saved to: data/segmented_clips
